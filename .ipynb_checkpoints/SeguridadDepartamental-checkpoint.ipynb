# %% [markdown]
# ## Analisis de datos

# %% [markdown]
# #### Creamos un dataframe con los datos de general data y lo fragmentamos y guardamos en un csv por departamento

# %%
import os
import pandas as pd

# %%
# Carga datos en un DataFrame
general_data = pd.read_csv('general_data.csv', low_memory=False)
general_data =  general_data[~general_data["departamento"].isin(["QUITO", "MADRID","NEW YORK","NEW JERSEY","FLORIDA"])]

def csv_by_filter(data, filter_column, output_folder, out = True):
    # Especifica la carpeta donde guardar los archivos CSV
    os.makedirs(output_folder, exist_ok=True)  # Crea la carpeta si no existe

    # Filtra y guarda un CSV para cada departamento
    for filter_column, data in general_data.groupby('departamento'):
        # Genera el nombre del archivo para cada departamento
        output_file = os.path.join(output_folder, f"{filter_column}.csv")
        if (out):
            print(f"Guardando {output_file}... con {len(data)} filas")
        # Guarda el DataFrame filtrado como CSV
        data.to_csv(output_file, index=False)
    if (out):
        print("Archivos CSV generados en la carpeta:", output_folder)

# Filtra y guarda un CSV para cada departamento
csv_by_filter(general_data, 'departamento', 'departamentos', out = False)

# %%
cauca = pd.read_csv('departamentos/Cauca.csv', low_memory=False)

# %%
# Out:
#        departamento      municipio codigo_dane fecha_hecho     genero  \
# 0          AMAZONAS   LETICIA    91001000   1/01/2010  MASCULINO
# 1          AMAZONAS   LETICIA    91001000   1/01/2010  MASCULINO
# 2          AMAZONAS   LETICIA    91001000   1/01/2010  MASCULINO
# 3          AMAZONAS   LETICIA    91001000   2/01/2010  MASCULINO
# 4          AMAZONAS   LETICIA    91001000   2/01/2010  MASCULINO
# ...             ...            ...         ...         ...        ...
# 839788      VICHADA  SANTA ROSALÍA    99624000   7/02/2015  MASCULINO
# 839789      VICHADA  SANTA ROSALÍA    99624000   8/02/2015  MASCULINO
# 839790      VICHADA  SANTA ROSALÍA    99624000  11/02/2015   FEMENINO
# 839791      VICHADA  SANTA ROSALÍA    99624000  22/04/2015  MASCULINO
# 839792      VICHADA  SANTA ROSALÍA    99624000  25/05/2015  MASCULINO
#
#                              descripcion_conducta_captura grupo_etario  \
# 0         ARTÍCULO 429. VIOLENCIA CONTRA SERVIDOR PÚBLICO      ADULTOS
# 1       ARTÍCULO 376. TRÁFICO. FABRICACIÓN O PORTE DE ...      ADULTOS
# 2                       ARTÍCULO 111. LESIONES PERSONALES      ADULTOS
# 3                         ARTÍCULO 239. HURTO RESIDENCIAS      ADULTOS
# 4       ARTÍCULO 376. TRÁFICO. FABRICACIÓN O PORTE DE ...      ADULTOS
# ...                                                   ...          ...
# 839788                   ARTÍCULO 239. HURTO MOTOCICLETAS      ADULTOS
# 839789                  ARTÍCULO 111. LESIONES PERSONALES      ADULTOS
# 839790                  ARTÍCULO 111. LESIONES PERSONALES      ADULTOS
# 839791  ARTÍCULO 376. TRÁFICO. FABRICACIÓN O PORTE DE ...      ADULTOS
# 839792  ARTÍCULO 376. TRÁFICO. FABRICACIÓN O PORTE DE ...      ADULTOS
#
#         cantidad
# 0              1
# 1              1
# 2              2
# 3              1
# 4              1
# ...          ...
# 839788         1
# 839789         2
# 839790         1
# 839791         1
# 839792         1
#
# [839775 rows x 8 columns]
